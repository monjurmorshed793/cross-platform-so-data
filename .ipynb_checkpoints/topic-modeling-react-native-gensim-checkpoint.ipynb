# %%
import nltk


nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\monju\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\monju\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\monju\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
import re

import numpy as np
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score,precision_recall_curve,roc_curve,plot_precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.decomposition import PCA, TruncatedSVD
import time
import matplotlib.patches as mpatches
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
import gc

from gensim.corpora import Dictionary
from gensim.models import LsiModel
gc.enable()
# Out:
# C:\tools\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# %%time 
posts=pd.read_csv('D:\so-data\PostsChosenV1.csv' , index_col='Id', )
# postTagsRawData = pd.read_csv('PostTagsV3.csv', chunksize=1000)
# postTagsRawData = pd.read_excel('PostsTags2.xlsx')
print(posts)
# Out:
#           AcceptedAnswerId  AnswerCount  \
# Id
# 1468404            1549052            3
# 1583856            1634592           14
# 1914947            1915407            4
# 1961341            1961838            1
# 2039387            2044192            4
# ...                    ...          ...
# 66394506          66397036            1
# 66394874          66394940            1
# 66400722          66400807            1
# 66402094          66403323            1
# 66405059          66405291            2
#
#                                                        Body  \
# Id
# 1468404   <p>Does mono touch allow you to do cross iPhon...
# 1583856   <p>After sitting through a session today on Mo...
# 1914947   <p>What is the best approach to implement tabs...
# 1961341   <p>How can I check internet access with MonoTo...
# 2039387   <p>I'm new to MonoTouch and iPhone development...
# ...                                                     ...
# 66394506  <p>I am trying to change the text of a <code>T...
# 66394874  <p>I'm working on a Flutter app which needs up...
# 66400722  <p>I have Node.js app, served by express, with...
# 66402094  <p>I have birthdays as timestamp stored in my ...
# 66405059  <p>I have two lists of integers in Dart that a...
#
#                        ClosedDate  CommentCount CommunityOwnedDate  \
# Id
# 1468404                       NaN             0                NaN
# 1583856   2019-09-23 16:34:03.127             1                NaN
# 1914947                       NaN             0                NaN
# 1961341                       NaN             1                NaN
# 2039387                       NaN             1                NaN
# ...                           ...           ...                ...
# 66394506                      NaN             0                NaN
# 66394874                      NaN             0                NaN
# 66400722                      NaN             0                NaN
# 66402094                      NaN             2                NaN
# 66405059                      NaN             0                NaN
#
#                      CreationDate  FavoriteCount         LastActivityDate  \
# Id
# 1468404   2009-09-23 20:42:43.883              2  2009-10-10 20:52:40.330
# 1583856   2009-10-18 02:47:39.653             91  2019-09-23 14:03:02.387
# 1914947   2009-12-16 14:23:59.397              5  2019-05-21 10:06:27.997
# 1961341   2009-12-25 15:38:21.420              2  2012-05-23 07:10:33.650
# 2039387   2010-01-11 01:12:49.940              2  2014-01-19 15:43:12.283
# ...                           ...            ...                      ...
# 66394506  2021-02-27 00:40:10.913              0  2021-02-27 08:44:47.877
# 66394874  2021-02-27 01:51:18.910              0  2021-02-27 04:55:46.833
# 66400722  2021-02-27 16:08:10.713              0  2021-02-27 17:42:53.847
# 66402094  2021-02-27 18:27:54.570              0  2021-02-27 20:48:58.980
# 66405059  2021-02-28 01:23:23.327              0  2021-02-28 05:25:16.493
#
#                      LastEditDate LastEditorDisplayName  LastEditorUserId  \
# Id
# 1468404   2009-09-23 20:45:37.153                   NaN             25981
# 1583856   2012-03-07 16:08:46.430              user1228                 0
# 1914947   2019-05-21 10:06:27.997                   NaN           4751173
# 1961341   2009-12-25 18:33:38.633                   NaN             30618
# 2039387   2014-01-19 15:43:12.283                   NaN            578411
# ...                           ...                   ...               ...
# 66394506  2021-02-27 01:25:55.750                   NaN          15101910
# 66394874  2021-02-27 04:55:46.833                   NaN            209103
# 66400722  2021-02-27 17:42:53.847                   NaN          15249278
# 66402094                      NaN                   NaN                 0
# 66405059                      NaN                   NaN                 0
#
#           OwnerUserId  ParentId  PostTypeId  Score  \
# Id
# 1468404        139096         0           1      3
# 1583856        142017         0           1    273
# 1914947         78101         0           1      6
# 1961341         34155         0           1     14
# 2039387        247706         0           1     14
# ...               ...       ...         ...    ...
# 66394506     15101910         0           1      0
# 66394874     13745697         0           1     -1
# 66400722     15249278         0           1      0
# 66402094      4338278         0           1      0
# 66405059        59195         0           1      0
#
#                                                        Tags  \
# Id
# 1468404                <iphone><communication><xamarin.ios>
# 1583856                <c#><objective-c><mono><xamarin.ios>
# 1914947     <iphone><uiview><uiviewcontroller><xamarin.ios>
# 1961341                               <iphone><xamarin.ios>
# 2039387                               <iphone><xamarin.ios>
# ...                                                     ...
# 66394506  <c#><android><xamarin><xamarin.android><androi...
# 66394874  <flutter><google-cloud-firestore><async-await>...
# 66400722                        <node.js><reactjs><express>
# 66402094                           <google-cloud-firestore>
# 66405059                                             <dart>
#
#                                                       Title  ViewCount
# Id
# 1468404         Cross iPhone communication using mono touch       1464
# 1583856    How to decide between MonoTouch and Objective-C?      28366
# 1914947                        Web-like tabs for the iPhone       1053
# 1961341            Check for internet access with monotouch       5548
# 2039387    Images in Interface Builder when using MonoTouch       4257
# ...                                                     ...        ...
# 66394506       Change text of TextView on ImageButton click         47
# 66394874                  Why Flutter "await" doesn't wait?         38
# 66400722  Image from express static folder is not appear...         20
# 66402094  Firestore query for a date field where the yea...         10
# 66405059  How can I add the matching elements of two lis...         24
#
# [265020 rows x 19 columns]
# Wall time: 4.29 s
# <decorator-gen-55>:2: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
#posts = posts.sample(10, replace=False).reset_index(drop=True)

# %%
from collections import defaultdict

def transform_text(text): 

    soup = BeautifulSoup(text)
    for elm in soup.find_all():
        if '<code>'== str(elm)[0:6]:
            elm.decompose()
    textStr = str(soup.get_text())
#     textStr = textStr.replace('<html>','')
#     textStr = textStr.replace('</html>','')
#     textStr = textStr.replace('<body>','')
#     textStr = textStr.replace('</body>','')
#     textStr = textStr.replace('<p>','')
#     textStr = textStr.replace('</p>','')
#     textStr = textStr.replace('<pre>','')
#     textStr = textStr.replace('</pre>','')
    
    
#     remove lines
    textStr = textStr.strip()
    # remove numbers
    textStr = re.sub(r"\d","", textStr)
    #lower document
    tokens = word_tokenize(textStr.lower())
    
    # remove stop words
    stop_words = set(stopwords.words('english'))
    stop_words.update(['.',',','"',"'",'?','!',':', ";",', ',',  ',',   ', '(',')','[',']','{','}','#','...','--',"'s",'also',
                      '&','-','--','=','known','mi','km','$',"'",'`'])
    stopped_tokens = [token for token in tokens if token not in stop_words]

    
    # PorterStemmer is used to make the root word, like Paying to 'play'.
    ps = PorterStemmer()
    
    stemmer = []
    for s in stopped_tokens:
        if s.isalpha():
            stemmer.append(ps.stem(s))
#     stemmer = [s for s in stopped_tokens ps.stem(s)]
    
    lemmatizer = WordNetLemmatizer()
    
    lemmatized_tokens = [lemmatizer.lemmatize(i, pos="n") for i in stemmer]
    
    frequency = defaultdict(int)
    
    for lemmatized_token in lemmatized_tokens:
        frequency[lemmatized_token]+=1
    
    converted_lemmatized_tokens = []
            
    for lemmatized_token in lemmatized_tokens:
        if frequency[lemmatized_token]>1:
            converted_lemmatized_tokens.append(lemmatized_token)
    
    return converted_lemmatized_tokens

# %%
transformedPosts = []

for row in posts.itertuples(index=True, name='Pandas'):
    transformedPosts.append(transform_text(row.Body))

# %%
print(transformedPosts)
# Out:
# [['code', 'success', 'detect', 'scroll', 'work', 'follow', 'item', 'get', 'ad', 'list', 'start', 'scroll', 'work', 'fine', 'method', 'anim', 'make', 'simpl', 'anim', 'either', 'half', 'size', 'object', 'make', 'full', 'work', 'fine', 'howev', 'click', 'new', 'categori', 'chang', 'content', 'list', 'itemappear', 'get', 'trigger', 'cours', 'call', 'even', 'though', 'want', 'call', 'scrollev', 'would', 'abl', 'differenti', 'scroll', 'item', 'collect', 'chang', 'tri', 'io', 'updat', 'code'], ['scaffold', 'first', 'menu', 'second', 'place', 'scaffold', 'fetch', 'data', 'tri', 'achiev', 'abl', 'go', 'place', 'page', 'return', 'menu', 'page', 'must', 'reload', 'initst', 'first', 'page', 'menu', 'scaffold', 'someth', 'like', 'work', 'perfectli', 'second', 'someth', 'like', 'return', 'previou', 'page', 'press', 'initst', 'previou', 'page', 'stop', 'initialis', 'state', 'go', 'back', 'screen'], ['instruct', 'http', 'use', 'fetch', 'api', 'access', 'file', 'display', 'upload', 'medium', 'error', 'occur', 'fail', 'load', 'resourc', 'server', 'respond', 'statu', 'code', 'tri'], ['tri', 'build', 'simpl', 'list', 'compon', 'display', 'imag', 'titl', 'click', 'titl', 'open', 'correspond', 'imag', 'al', 'work', 'fine', 'problem', 'rest', 'titl', 'list', 'push', 'underneath', 'imag', 'desir', 'result', 'imag', 'display', 'right', 'list', 'without', 'affect', 'list', 'tri', 'separ', 'compon', 'two', 'compon', 'imag', 'call', 'ternari', 'oper', 'put', 'compon', 'like', 'seem', 'fix', 'problem', 'project', 'list', 'current', 'result', 'titl', 'click', 'desir', 'result'], ['tie', 'creat', 'compon', 'tag', 'tri', 'bind', 'attribut', 'sampl', 'get', 'error', 'ca', 'bind', 'sinc', 'nativ', 'properti', 'direct', 'plea', 'fix', 'typo', 'add', 'direct', 'list', 'fix', 'drop', 'thank', 'advanc'], ['access', 'compon', 'method', 'outsid', 'reactj', 'possibl', 'way', 'solv', 'consid', 'code'], ['work', 'web', 'app', 'use', 'modal', 'dialog', 'multipl', 'modal', 'dialog', 'render', 'app', 'differ', 'place', 'differ', 'compon', 'construct', 'differ', 'level', 'hierarchi', 'howev', 'ever', 'one', 'modal', 'dialog', 'activ', 'time', 'never', 'problem', 'approach', 'rel', 'new', 'react', 'somehow', 'end', 'situat', 'two', 'modal', 'dialog', 'open', 'close', 'suppos', 'button', 'work', 'edit', 'form', 'anymor', 'select', 'header', 'text', 'exampl', 'dialog', 'work', 'ad', 'dialog', 'place', 'guess', 'least', 'someth', 'need', 'watch', 'work', 'multipl', 'modal', 'dialog', 'gener', 'like', 'render', 'modal', 'dialog', 'modal', 'dialogu', 'question', 'render', 'anoth', 'compon', 'somewher', 'like'], ['want', 'know', 'firebas', 'perform', 'multipl', 'updat', 'document', 'batch', 'caus', 'singl', 'write', 'multipl', 'write', 'instanc', 'exampl', 'code', 'javascript', 'singl', 'write', 'document', 'updat', 'everyth', 'two', 'write', 'one', 'updat', 'answer', 'chang', 'one', 'two', 'oper', 'set', 'instead', 'updat', 'thank', 'advanc'], ['work', 'download', 'imag', 'servic', 'imag', 'beyond', 'display', 'area', 'know', 'due', 'size', 'imag', 'ca', 'set', 'item', 'like', 'suggest', 'possibl'], ['could', 'plea', 'tell', 'redirect', 'respect', 'compon', 'react', 'redirect', 'key', 'found', 'goe', 'respect', 'compon', 'follow', 'step', 'add', 'url', 'redirect', 'load', 'compon', 'local', 'storag', 'key', 'valu', 'current', 'abl', 'redirect', 'home', 'valu', 'local', 'higher', 'oder', 'compon', 'demo', 'app', 'http', 'run', 'applic', 'url', 'full', 'url', 'http', 'expect', 'redirect', 'load', 'compon']]

# %%
from gensim import corpora


dictionary = corpora.Dictionary(transformedPosts)
corpus = [dictionary.doc2bow(text) for text in transformedPosts]

# %%
print(dictionary)
# Out:
# Dictionary(26418 unique tokens: ['iphon', 'develop', 'mono', 'monotouch', 'applic']...)

# %%
from gensim import models

model = models.LdaModel(corpus, id2word=dictionary, num_topics=30, iterations=1000 )

# %%
print(model.num_topics)
# Out:
# 30

# %%
top_topics = model.top_topics(corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / 30

print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -5.9604.
# [([(0.12676206, 'select'),
#    (0.11055465, 'insid'),
#    (0.09468146, 'id'),
#    (0.07109982, 'tabl'),
#    (0.06808052, 'check'),
#    (0.059572518, 'option'),
#    (0.056104325, 'row'),
#    (0.042093962, 'gener'),
#    (0.03976842, 'html'),
#    (0.037513316, 'tag'),
#    (0.03644111, 'checkbox'),
#    (0.032377765, 'column'),
#    (0.024167353, 'multipl'),
#    (0.022926662, 'alreadi'),
#    (0.02108554, 'chart'),
#    (0.017341973, 'achiev'),
#    (0.016309725, 'one'),
#    (0.015507285, 'creat'),
#    (0.012372905, 'fill'),
#    (0.010142203, 'popul')],
#   -4.407736757959117),
#  ([(0.24929322, 'firebas'),
#    (0.07629263, 'map'),
#    (0.07595239, 'rout'),
#    (0.073029466, 'event'),
#    (0.05862678, 'queri'),
#    (0.056469187, 'login'),
#    (0.034655575, 'googl'),
#    (0.03465312, 'databas'),
#    (0.033766836, 'activ'),
#    (0.031192092, 'rule'),
#    (0.030427707, 'trigger'),
#    (0.026635071, 'sign'),
#    (0.026211893, 'listen'),
#    (0.024261234, 'exist'),
#    (0.022132969, 'account'),
#    (0.017874721, 'creat'),
#    (0.014839768, 'regist'),
#    (0.014446768, 'allow'),
#    (0.010331564, 'secur'),
#    (0.008310679, 'let')],
#   -4.461227187301862),
#  ([(0.12246709, 'way'),
#    (0.11302664, 'new'),
#    (0.09802116, 'form'),
#    (0.0861003, 'prop'),
#    (0.07788714, 'know'),
#    (0.062543124, 'json'),
#    (0.0572367, 'server'),
#    (0.045132212, 'abl'),
#    (0.035575487, 'write'),
#    (0.025777126, 'submit'),
#    (0.025625948, 'defin'),
#    (0.024598436, 'understand'),
#    (0.022665668, 'creat'),
#    (0.020921588, 'put'),
#    (0.02013243, 'inform'),
#    (0.017384607, 'simpl'),
#    (0.016892528, 'structur'),
#    (0.012882221, 'chat'),
#    (0.012810915, 'tutori'),
#    (0.009057291, 'done')],
#   -4.506208168193423),
#  ([(0.347341, 'like'),
#    (0.15222406, 'would'),
#    (0.09674279, 'make'),
#    (0.05594148, 'messag'),
#    (0.046389885, 'someth'),
#    (0.041015122, 'could'),
#    (0.03175673, 'node'),
#    (0.028432816, 'loop'),
#    (0.026701504, 'side'),
#    (0.026060829, 'print'),
#    (0.0192713, 'one'),
#    (0.015544896, 'think'),
#    (0.0148207005, 'sinc'),
#    (0.011572267, 'alert'),
#    (0.0112587195, 'reactj'),
#    (0.010539871, 'async'),
#    (0.008588574, 'avail'),
#    (0.007970526, 'throw'),
#    (0.0070744297, 'might'),
#    (0.005544482, 'creat')],
#   -4.566755153400072),
#  ([(0.12936823, 'project'),
#    (0.08721963, 'return'),
#    (0.080629736, 'issu'),
#    (0.07867905, 'android'),
#    (0.06999944, 'fetch'),
#    (0.05557018, 'collect'),
#    (0.049303908, 'creat'),
#    (0.047535937, 'implement'),
#    (0.042483214, 'folder'),
#    (0.03456931, 'librari'),
#    (0.032804675, 'find'),
#    (0.023226563, 'xamarin'),
#    (0.022191241, 'task'),
#    (0.0202442, 'c'),
#    (0.018037554, 'correct'),
#    (0.015856303, 'memori'),
#    (0.014454141, 'studio'),
#    (0.014079228, 'last'),
#    (0.013688384, 'io'),
#    (0.011643764, 'target')],
#   -4.81485203484635),
#  ([(0.31616315, 'work'),
#    (0.14820676, 'imag'),
#    (0.07024541, 'code'),
#    (0.056202993, 'problem'),
#    (0.053748023, 'look'),
#    (0.030327972, 'upload'),
#    (0.02978863, 'card'),
#    (0.029086404, 'filter'),
#    (0.0246474, 'header'),
#    (0.023135703, 'fine'),
#    (0.021552712, 'solut'),
#    (0.01758174, 'backend'),
#    (0.012793136, 'fix'),
#    (0.01130232, 'thing'),
#    (0.010654909, 'everyth'),
#    (0.009812219, 'pictur'),
#    (0.009371533, 'well'),
#    (0.008932673, 'howev'),
#    (0.008860143, 'correctli'),
#    (0.006693698, 'camera')],
#   -4.84672756925143),
#  ([(0.14623667, 'display'),
#    (0.12105595, 'time'),
#    (0.091799736, 'first'),
#    (0.08897964, 'exampl'),
#    (0.08148398, 'access'),
#    (0.051135603, 'second'),
#    (0.046238102, 'respons'),
#    (0.04167161, 'everi'),
#    (0.02837736, 'model'),
#    (0.023601599, 'take'),
#    (0.02111842, 'approach'),
#    (0.020261113, 'comment'),
#    (0.018289486, 'via'),
#    (0.017987518, 'layout'),
#    (0.016908087, 'appli'),
#    (0.016651431, 'actual'),
#    (0.014333297, 'photo'),
#    (0.012927615, 'cach'),
#    (0.011507918, 'share'),
#    (0.011275149, 'properli')],
#   -4.87715920714648),
#  ([(0.31147733, 'user'),
#    (0.16572684, 'updat'),
#    (0.055986285, 'databas'),
#    (0.050462585, 'log'),
#    (0.037955336, 'read'),
#    (0.033184264, 'line'),
#    (0.030718787, 'connect'),
#    (0.027017646, 'differ'),
#    (0.02369395, 'store'),
#    (0.022134753, 'valid'),
#    (0.0213967, 'locat'),
#    (0.019237908, 'retriev'),
#    (0.01847874, 'give'),
#    (0.016783498, 'paramet'),
#    (0.016637819, 'download'),
#    (0.014959201, 'say'),
#    (0.014351617, 'password'),
#    (0.009745664, 'cell'),
#    (0.009645703, 'admin'),
#    (0.009304719, 'reset')],
#   -5.099057690692608),
#  ([(0.26070827, 'error'),
#    (0.2499634, 'function'),
#    (0.22226866, 'code'),
#    (0.037141945, 'variabl'),
#    (0.03092663, 'import'),
#    (0.024363488, 'start'),
#    (0.022850843, 'product'),
#    (0.016857272, 'path'),
#    (0.012559074, 'part'),
#    (0.0113385795, 'got'),
#    (0.0107474085, 'end'),
#    (0.00880688, 'posit'),
#    (0.008759164, 'crash'),
#    (0.0086635845, 'doc'),
#    (0.008469304, 'b'),
#    (0.00816251, 'compil'),
#    (0.008154695, 'x'),
#    (0.007560664, 'declar'),
#    (0.006004297, 'manag'),
#    (0.004301322, 'featur')],
#   -5.127554398450436),
#  ([(0.14446467, 'class'),
#    (0.13538563, 'document'),
#    (0.11437972, 'http'),
#    (0.07691498, 'url'),
#    (0.046866834, 'save'),
#    (0.037945546, 'local'),
#    (0.037474778, 'email'),
#    (0.03700048, 'receiv'),
#    (0.03673214, 'cs'),
#    (0.033558007, 'context'),
#    (0.029958973, 'dropdown'),
#    (0.029637523, 'plugin'),
#    (0.022048615, 'creat'),
#    (0.020351553, 'instanc'),
#    (0.019564452, 'instead'),
#    (0.018948361, 'assign'),
#    (0.014854913, 'block'),
#    (0.0128272325, 'constructor'),
#    (0.012681562, 'basic'),
#    (0.01213444, 'copi')],
#   -5.243835392791292),
#  ([(0.38867477, 'app'),
#    (0.08054901, 'build'),
#    (0.06046684, 'version'),
#    (0.049732678, 'fail'),
#    (0.04259759, 'devic'),
#    (0.042420402, 'instal'),
#    (0.034835026, 'null'),
#    (0.031788975, 'deploy'),
#    (0.027711364, 'io'),
#    (0.0198328, 'webpack'),
#    (0.018592983, 'command'),
#    (0.015262221, 'applic'),
#    (0.013634944, 'host'),
#    (0.013263595, 'debug'),
#    (0.011387097, 'cordova'),
#    (0.00945312, 'develop'),
#    (0.008879733, 'e'),
#    (0.008369924, 'xcode'),
#    (0.008247387, 'design'),
#    (0.00784132, 'transact')],
#   -5.337560446186796),
#  ([(0.4170465, 'compon'),
#    (0.17221406, 'react'),
#    (0.10414405, 'render'),
#    (0.06609952, 'pas'),
#    (0.03864205, 'action'),
#    (0.03664973, 'store'),
#    (0.026076352, 'token'),
#    (0.0139554, 'modul'),
#    (0.011932954, 'dispatch'),
#    (0.01143828, 'nest'),
#    (0.008329178, 'day'),
#    (0.0068707555, 'express'),
#    (0.006634345, 'differ'),
#    (0.006323353, 'dom'),
#    (0.005211454, 'timer'),
#    (0.0046491297, 'howev'),
#    (0.0043913457, 'snapshot'),
#    (0.004165336, 'bundl'),
#    (0.0038338108, 'creat'),
#    (0.0029800106, 'built')],
#   -5.424183280730576),
#  ([(0.26519474, 'want'),
#    (0.10249465, 'input'),
#    (0.090108424, 'text'),
#    (0.08307897, 'name'),
#    (0.06669093, 'ad'),
#    (0.05676281, 'key'),
#    (0.04666137, 'color'),
#    (0.037856217, 'remov'),
#    (0.029202681, 'order'),
#    (0.027358135, 'warn'),
#    (0.026375402, 'provid'),
#    (0.02094917, 'enter'),
#    (0.015468259, 'format'),
#    (0.0151037285, 'group'),
#    (0.01394645, 'statu'),
#    (0.013259704, 'db'),
#    (0.008321118, 'clear'),
#    (0.0068638893, 'sampl'),
#    (0.00682083, 'contact'),
#    (0.006387312, 'reason')],
#   -5.523233021160142),
#  ([(0.24583411, 'call'),
#    (0.20918612, 'object'),
#    (0.121936426, 'method'),
#    (0.084292725, 'element'),
#    (0.038341366, 'return'),
#    (0.03434416, 'servic'),
#    (0.025340429, 'storag'),
#    (0.01860684, 'refer'),
#    (0.016610535, 'sort'),
#    (0.012656267, 'angular'),
#    (0.012636185, 'match'),
#    (0.012240868, 'caus'),
#    (0.0122294035, 'wrap'),
#    (0.0115834195, 'includ'),
#    (0.011099432, 'realli'),
#    (0.010705842, 'separ'),
#    (0.010201654, 'level'),
#    (0.009819584, 'behavior'),
#    (0.008997184, 'futur'),
#    (0.008385622, 'articl')],
#   -5.640039378316695),
#  ([(0.13500369, 'link'),
#    (0.1227453, 'hook'),
#    (0.1064334, 'style'),
#    (0.102938704, 'open'),
#    (0.046436302, 'mobil'),
#    (0.04103071, 'handl'),
#    (0.037348855, 'close'),
#    (0.033126548, 'keep'),
#    (0.03130409, 'dialog'),
#    (0.030931195, 'configur'),
#    (0.02948719, 'jqueri'),
#    (0.027733533, 'toggl'),
#    (0.02466476, 'solv'),
#    (0.023094118, 'site'),
#    (0.018354995, 'never'),
#    (0.01800953, 'problem'),
#    (0.015951129, 'selector'),
#    (0.015322559, 'full'),
#    (0.013446913, 'snippet'),
#    (0.013445411, 'person')],
#   -5.842121639928605),
#  ([(0.1808579, 'set'),
#    (0.17491038, 'need'),
#    (0.078468844, 'send'),
#    (0.07573047, 'widget'),
#    (0.06568632, 'notif'),
#    (0.06070658, 'number'),
#    (0.03454225, 'within'),
#    (0.034302738, 'push'),
#    (0.03088041, 'messag'),
#    (0.02619598, 'step'),
#    (0.023803351, 'true'),
#    (0.021744788, 'success'),
#    (0.018143175, 'auth'),
#    (0.01776501, 'timestamp'),
#    (0.0129390415, 'charact'),
#    (0.011081173, 'rest'),
#    (0.01038538, 'dashboard'),
#    (0.009637056, 'realtim'),
#    (0.0094876215, 'domain'),
#    (0.009269444, 'learn')],
#   -6.15758448971084),
#  ([(0.37485906, 'get'),
#    (0.22507934, 'valu'),
#    (0.090375304, 'type'),
#    (0.04889603, 'post'),
#    (0.031839393, 'consol'),
#    (0.02214633, 'output'),
#    (0.022064973, 'case'),
#    (0.016347315, 'video'),
#    (0.016209884, 'sure'),
#    (0.013389481, 'play'),
#    (0.012277479, 'titl'),
#    (0.011711327, 'still'),
#    (0.010526671, 'theme'),
#    (0.009252002, 'mode'),
#    (0.008940841, 'alway'),
#    (0.007742846, 'cooki'),
#    (0.007607348, 'suggest'),
#    (0.007526617, 'slider'),
#    (0.0073833545, 'info'),
#    (0.006586389, 'enabl')],
#   -6.18254930633608),
#  ([(0.13261887, 'view'),
#    (0.12901947, 'properti'),
#    (0.10533935, 'help'),
#    (0.06820951, 'anoth'),
#    (0.06516818, 'anim'),
#    (0.058846194, 'redirect'),
#    (0.05419558, 'nativ'),
#    (0.052711062, 'control'),
#    (0.050340928, 'execut'),
#    (0.040169057, 'main'),
#    (0.034943167, 'grid'),
#    (0.03328586, 'fire'),
#    (0.027106557, 'place'),
#    (0.01953176, 'center'),
#    (0.014174597, 'present'),
#    (0.012690075, 'area'),
#    (0.012004486, 'swipe'),
#    (0.010581775, 'lot'),
#    (0.010150754, 'direct'),
#    (0.009784759, 'thread')],
#   -6.293843710814376),
#  ([(0.19348592, 'array'),
#    (0.13935904, 'follow'),
#    (0.13181874, 'show'),
#    (0.093689606, 'one'),
#    (0.09035455, 'screen'),
#    (0.05604616, 'contain'),
#    (0.04934403, 'tab'),
#    (0.047043655, 'two'),
#    (0.02404857, 'size'),
#    (0.01807886, 'box'),
#    (0.016851636, 'switch'),
#    (0.015774572, 'entri'),
#    (0.01246849, 'come'),
#    (0.009435946, 'audio'),
#    (0.009178309, 'jsx'),
#    (0.008657197, 'font'),
#    (0.008620573, 'insert'),
#    (0.007997177, 'viewmodel'),
#    (0.0067257327, 'whenev'),
#    (0.005743178, 'three')],
#   -6.322820257161056),
#  ([(0.25228277, 'run'),
#    (0.10054442, 'question'),
#    (0.06269331, 'div'),
#    (0.04016411, 'answer'),
#    (0.033099834, 'move'),
#    (0.032642286, 'next'),
#    (0.031820666, 'point'),
#    (0.027281685, 'usernam'),
#    (0.026051516, 'oper'),
#    (0.024763614, 'perform'),
#    (0.023843212, 'noth'),
#    (0.023650343, 'disabl'),
#    (0.023367686, 'shown'),
#    (0.021259727, 'game'),
#    (0.016120514, 'logic'),
#    (0.015993668, 'xaml'),
#    (0.014592562, 'facebook'),
#    (0.01358441, 'hit'),
#    (0.0131632155, 'duplic'),
#    (0.012913434, 'iphon')],
#   -6.484963431087664),
#  ([(0.11201609, 'seem'),
#    (0.06472647, 'browser'),
#    (0.06096508, 'happen'),
#    (0.052832257, 'without'),
#    (0.051148597, 'even'),
#    (0.04242084, 'window'),
#    (0.041587442, 'wrong'),
#    (0.03743362, 'phone'),
#    (0.037189372, 'v'),
#    (0.033646878, 'attempt'),
#    (0.03233798, 'singl'),
#    (0.028771289, 'develop'),
#    (0.027290642, 'marker'),
#    (0.025661884, 'webview'),
#    (0.024924243, 'reload'),
#    (0.023783902, 'chrome'),
#    (0.023126692, 'support'),
#    (0.019386219, 'better'),
#    (0.015872585, 'java'),
#    (0.015830036, 'increment')],
#   -6.522894148343719),
#  ([(0.48903498, 'data'),
#    (0.11562731, 'test'),
#    (0.044526327, 'edit'),
#    (0.039813053, 'scroll'),
#    (0.029964443, 'im'),
#    (0.029677847, 'plea'),
#    (0.025925083, 'height'),
#    (0.022962108, 'specif'),
#    (0.021938859, 'width'),
#    (0.021001952, 'top'),
#    (0.018912353, 'bottom'),
#    (0.014461853, 'section'),
#    (0.013952459, 'space'),
#    (0.011126005, 'previou'),
#    (0.011082914, 'resolv'),
#    (0.008331671, 'occur'),
#    (0.008124319, 'figur'),
#    (0.00789016, 'launch'),
#    (0.0075718295, 'anyth'),
#    (0.0073496066, 'draw')],
#   -6.594203032583444),
#  ([(0.19801804, 'list'),
#    (0.1555614, 'item'),
#    (0.11288439, 'field'),
#    (0.11201008, 'add'),
#    (0.0620529, 'result'),
#    (0.053653248, 'search'),
#    (0.030243305, 'dynam'),
#    (0.019230383, 'detail'),
#    (0.017226929, 'categori'),
#    (0.015410046, 'export'),
#    (0.014038548, 'player'),
#    (0.010915828, 'one'),
#    (0.010594273, 'countri'),
#    (0.008866019, 'iter'),
#    (0.008632562, 'thank'),
#    (0.008015833, 'demo'),
#    (0.0077495747, 'creat'),
#    (0.0077199056, 'someon'),
#    (0.0074879397, 'calendar'),
#    (0.007049062, 'red')],
#   -6.695311208247394),
#  ([(0.2567364, 'state'),
#    (0.20974828, 'chang'),
#    (0.100911535, 'child'),
#    (0.061041467, 'parent'),
#    (0.05117599, 'delet'),
#    (0.036013663, 'packag'),
#    (0.03242441, 'menu'),
#    (0.025814004, 'initi'),
#    (0.020372644, 'empti'),
#    (0.017562151, 'record'),
#    (0.017241133, 'except'),
#    (0.01689996, 'bind'),
#    (0.016455624, 'label'),
#    (0.011873572, 'handler'),
#    (0.011791907, 'idea'),
#    (0.010029208, 'directori'),
#    (0.008722923, 'textfield'),
#    (0.008454451, 'onclick'),
#    (0.008039784, 'word'),
#    (0.007598623, 'radio')],
#   -6.9122519269103915),
#  ([(0.47006124, 'tri'),
#    (0.061070494, 'string'),
#    (0.051590778, 'current'),
#    (0.045560647, 'date'),
#    (0.039755736, 'icon'),
#    (0.039387804, 'custom'),
#    (0.037407115, 'ionic'),
#    (0.027436629, 'depend'),
#    (0.024614263, 'base'),
#    (0.022565916, 'bar'),
#    (0.021007136, 'condit'),
#    (0.01974123, 'default'),
#    (0.012749222, 'fals'),
#    (0.0117899645, 'attribut'),
#    (0.010649828, 'permiss'),
#    (0.010592843, 'count'),
#    (0.009837329, 'templat'),
#    (0.007747423, 'miss'),
#    (0.006495727, 'align'),
#    (0.005690337, 'progress')],
#   -6.976127808514081),
#  ([(0.65564114, 'use'),
#    (0.08794768, 'api'),
#    (0.042233344, 'applic'),
#    (0.026065763, 'cloud'),
#    (0.019352486, 'ui'),
#    (0.016298823, 'dart'),
#    (0.015433782, 'possibl'),
#    (0.013623908, 'ca'),
#    (0.012714652, 'convert'),
#    (0.010121667, 'callback'),
#    (0.009250296, 'javascript'),
#    (0.007306135, 'screenshot'),
#    (0.005481277, 'port'),
#    (0.0054003065, 'must'),
#    (0.0051856837, 'php'),
#    (0.004584889, 'outsid'),
#    (0.00444809, 'syntax'),
#    (0.004292536, 'bootstrap'),
#    (0.0042277453, 'global'),
#    (0.0034224421, 'drag')],
#   -7.30958025000918),
#  ([(0.31839383, 'button'),
#    (0.24096602, 'click'),
#    (0.051205263, 'content'),
#    (0.041022636, 'right'),
#    (0.032764737, 'back'),
#    (0.03198961, 'press'),
#    (0.029189346, 'listview'),
#    (0.026657645, 'home'),
#    (0.020393705, 'stream'),
#    (0.013569114, 'effect'),
#    (0.013498407, 'left'),
#    (0.012652733, 'navbar'),
#    (0.012171779, 'replac'),
#    (0.011544535, 'hide'),
#    (0.010666601, 'modifi'),
#    (0.01065381, 'slide'),
#    (0.009539323, 'limit'),
#    (0.008740633, 'hover'),
#    (0.007986872, 'sometim'),
#    (0.007914527, 'mount')],
#   -7.5140110952235855),
#  ([(0.08632478, 'modal'),
#    (0.08172029, 'reduc'),
#    (0.08014301, 'client'),
#    (0.068584256, 'authent'),
#    (0.06159694, 'background'),
#    (0.058252733, 'undefin'),
#    (0.056182176, 'web'),
#    (0.040285524, 'appear'),
#    (0.039592616, 'server'),
#    (0.03473579, 'profil'),
#    (0.03384193, 'websit'),
#    (0.031208782, 'complet'),
#    (0.027593432, 'drawer'),
#    (0.021822926, 'config'),
#    (0.018535338, 'process'),
#    (0.01835709, 'made'),
#    (0.017264316, 'session'),
#    (0.013977293, 'specifi'),
#    (0.013420235, 'white'),
#    (0.012877896, 'descript')],
#   -7.548963108366644),
#  ([(0.42257422, 'page'),
#    (0.14281878, 'load'),
#    (0.101123095, 'navig'),
#    (0.049577974, 'go'),
#    (0.03406685, 'refresh'),
#    (0.031193595, 'index'),
#    (0.02575501, 'script'),
#    (0.020637644, 'stack'),
#    (0.020032976, 'back'),
#    (0.014957463, 'expect'),
#    (0.010326857, 'focu'),
#    (0.010311009, 'arrow'),
#    (0.009277201, 'front'),
#    (0.008763296, 'extern'),
#    (0.008112471, 'upgrad'),
#    (0.007573782, 'analyt'),
#    (0.0075573022, 'ajax'),
#    (0.0070796385, 'spinner'),
#    (0.006125532, 'histori'),
#    (0.0051797824, 'problem')],
#   -7.774817213472244),
#  ([(0.3774928, 'file'),
#    (0.11506873, 'request'),
#    (0.111575074, 'see'),
#    (0.032171935, 'j'),
#    (0.030584283, 'found'),
#    (0.022124082, 'sdk'),
#    (0.018541332, 'note'),
#    (0.016329171, 'picker'),
#    (0.015070108, 'static'),
#    (0.014802679, 'sourc'),
#    (0.014796213, 'calcul'),
#    (0.0132008195, 'simul'),
#    (0.012336529, 'may'),
#    (0.011650931, 'mock'),
#    (0.011635542, 'fragment'),
#    (0.011475703, 'creat'),
#    (0.010627487, 'resourc'),
#    (0.010615068, 'book'),
#    (0.01060279, 'environ'),
#    (0.00843994, 'attach')],
#   -7.803106492201196)]

# %%
# %pinfo model

# %%
dir(model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapt_by_suffix',
#  '_apply',
#  '_load_specials',
#  '_save_specials',
#  '_smart_save',
#  'add_lifecycle_event',
#  'alpha',
#  'bound',
#  'callbacks',
#  'chunksize',
#  'clear',
#  'decay',
#  'diff',
#  'dispatcher',
#  'distributed',
#  'do_estep',
#  'do_mstep',
#  'dtype',
#  'eta',
#  'eval_every',
#  'expElogbeta',
#  'gamma_threshold',
#  'get_document_topics',
#  'get_term_topics',
#  'get_topic_terms',
#  'get_topics',
#  'id2word',
#  'inference',
#  'init_dir_prior',
#  'iterations',
#  'lifecycle_events',
#  'load',
#  'log_perplexity',
#  'minimum_phi_value',
#  'minimum_probability',
#  'num_terms',
#  'num_topics',
#  'num_updates',
#  'numworkers',
#  'offset',
#  'optimize_alpha',
#  'optimize_eta',
#  'passes',
#  'per_word_topics',
#  'print_topic',
#  'print_topics',
#  'random_state',
#  'save',
#  'show_topic',
#  'show_topics',
#  'state',
#  'sync_state',
#  'top_topics',
#  'update',
#  'update_alpha',
#  'update_eta',
#  'update_every']
