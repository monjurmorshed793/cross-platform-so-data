# %%
import sys
# !{sys.executable} -m pip install spacy
# !{sys.executable} -m pip install pyldavis
# !{sys.executable} -m spacy download en
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install biopython
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install tensorflow
# !{sys.executable} -m pip install imblearn
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install xgboost
# !{sys.executable} -m pip install pyod
# !{sys.executable} -m pip install lightgbm
# !{sys.executable} -m pip install catboost 
# !{sys.executable} -m pip install plotly
# !{sys.executable} -m pip install cufflinks
# !{sys.executable} -m pip install pyclustering
# !{sys.executable} -m pip install beautifulsoup4
# !{sys.executable} -m pip install algorithmia
# !{sys.executable} -m pip install paramiko
# !{sys.executable} -m pip install gensim==3.8.3

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim import models
from gensim.models import LdaModel, CoherenceModel
from gensim.models.wrappers import LdaMallet
import pprint

# spacy for lemmatization
import spacy
from spacy.lang.en import English

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

import pandas as pd
import numpy as np

import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\monju\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
reviews_datasets=pd.read_csv('D:/so-data/cordova-posts.csv'  )
# reviews_datasets=reviews_datasets.head(1000)
# postTagsRawData = pd.read_csv('PostTagsV3.csv', chunksize=1000)
# postTagsRawData = pd.read_excel('PostsTags2.xlsx')
print(reviews_datasets.head(20))
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          Id  AcceptedAnswerId  AnswerCount  \
# 0    475553            475576            3
# 1    957076            957273            4
# 2   2010956           2020385            1
# 3    838069            848302            5
# 4    937724            947072            2
# 5   2233292           2233312            7
# 6   1791298           1793588            1
# 7   2096328           2243265            3
# 8    773843           1505805           10
# 9   4147376           4195753            4
# 10  3939333           3939364            1
# 11  3974122           3979543            1
# 12  3930277           3982919            2
# 13  4066167           4089874           20
# 14  3897530           3941900            2
# 15  4195534           4199452            2
# 16  3958612           4246540            7
# 17  3983893           3984181            1
# 18  3075468           3076946            4
# 19  4039428           4049250            8
#
#                                                  Body  \
# 0   <p>I wonder if I can test landscape view using...
# 1   <p>What JavaScript Mobile development tool wou...
# 2   <p>I'm using PhoneGap 0.8 and I'd like to dete...
# 3   <p>I'm tyring to get phonegap up and running o...
# 4   <p>I recently stumbled into PhoneGap and I lov...
# 5   <p>I want to build a relatively simple version...
# 6   <p>I am trying to send a POST request to Drupa...
# 7   <p>I have created a search field on a mobile a...
# 8   <p>I'm experimenting with PhoneGap to develop ...
# 9   <p>By default jquery-mobile adds a back button...
# 10  <p>I have this script, which works great at th...
# 11  <p>Let said currently I want to pull a XML fil...
# 12  <p>After experimenting with a bunch of javascr...
# 13  <p>I wonder if I were to develop a mobile Web ...
# 14  <p>I'm trying to do a Tabpanel in Sencha Touch...
# 15  <p>i'm trying to update my sencha app from Ext...
# 16  <p>Has anyone been able to incorporate Charts ...
# 17  <p>Now the case, I want to develop a iPhone ap...
# 18  <p>I've read about phonegap which enables user...
# 19  <p>I'm creating a web-database driven offline ...
#
#                  ClosedDate  CommentCount CommunityOwnedDate  \
# 0                       NaN             0                NaN
# 1   2015-04-20 17:02:40.937             0                NaN
# 2                       NaN             0                NaN
# 3                       NaN             3                NaN
# 4                       NaN             3                NaN
# 5                       NaN             2                NaN
# 6                       NaN             1                NaN
# 7                       NaN             0                NaN
# 8                       NaN             3                NaN
# 9                       NaN             1                NaN
# 10                      NaN             0                NaN
# 11                      NaN             0                NaN
# 12                      NaN             0                NaN
# 13  2014-09-03 05:32:05.810             2                NaN
# 14                      NaN             0                NaN
# 15                      NaN             0                NaN
# 16                      NaN             0                NaN
# 17                      NaN             0                NaN
# 18  2012-08-21 03:57:45.833             0                NaN
# 19                      NaN             0                NaN
#
#                CreationDate  FavoriteCount         LastActivityDate  ...  \
# 0   2009-01-24 05:16:54.267              5  2016-11-16 12:31:53.453  ...
# 1   2009-06-05 17:20:44.613              1  2010-02-16 17:38:44.317  ...
# 2   2010-01-06 04:28:49.527              3  2010-03-02 07:48:13.103  ...
# 3   2009-05-08 03:09:39.223              1  2019-03-15 23:01:25.430  ...
# 4   2009-06-02 02:48:55.373              5  2010-03-05 15:51:13.780  ...
# 5   2010-02-09 23:24:46.513              5  2014-03-19 12:31:42.353  ...
# 6   2009-11-24 16:41:43.087              1  2010-06-09 21:00:08.937  ...
# 7   2010-01-19 19:18:08.563              3  2018-05-07 15:46:24.907  ...
# 8   2009-04-21 18:06:17.257             19  2017-12-10 15:59:36.850  ...
# 9   2010-11-10 17:46:06.757              6  2011-09-14 17:01:29.040  ...
# 10  2010-10-15 03:39:55.360              0  2010-10-15 18:58:23.973  ...
# 11  2010-10-20 01:33:10.283              0  2010-10-20 15:28:31.630  ...
# 12  2010-10-14 05:17:40.483              1  2010-10-20 22:47:07.143  ...
# 13  2010-11-01 01:45:40.650             30  2014-07-01 12:31:53.317  ...
# 14  2010-10-09 19:20:59.220              2  2011-03-14 14:37:33.940  ...
# 15  2010-11-16 15:06:18.277              0  2013-04-22 20:29:11.283  ...
# 16  2010-10-18 11:24:37.663              2  2013-03-17 08:56:42.577  ...
# 17  2010-10-21 02:37:44.493              1  2010-10-21 03:59:02.170  ...
# 18  2010-06-19 12:27:59.117              2  2012-04-17 22:44:48.960  ...
# 19  2010-10-28 03:01:04.310              4  2012-01-05 09:05:20.293  ...
#
#    PostTypeId Score                                               Tags  \
# 0           1    42              <cocoa-touch><cordova><ios-simulator>
# 1           1     3        <javascript><iphone><android><cordova><xui>
# 2           1     2  <iphone><accelerometer><cordova><gesture-recog...
# 3           1     3  <browser><blackberry><touchscreen><cordova><ri...
# 4           1     4             <iphone><android><blackberry><cordova>
# 5           1    20   <jquery><iphone><android><mobile><jquery-mobile>
# 6           1     0             <iphone><json><drupal><jsonp><cordova>
# 7           1     7                      <javascript><iphone><cordova>
# 8           1    61             <iphone><keyboard><uiwebview><cordova>
# 9           1    18                <javascript><jquery><jquery-mobile>
# 10          1     0          <javascript><xcode><conditional><cordova>
# 11          1     0         <iphone><xml><web-services><html><cordova>
# 12          1     0  <uitabbarcontroller><uitabbar><jqtouch><cordov...
# 13          1    69  <jquery-mobile><web-applications><sencha-touch...
# 14          1     3                  <javascript><extjs><sencha-touch>
# 15          1     3                              <extjs><sencha-touch>
# 16          1     9               <graph><charts><sencha-touch><extjs>
# 17          1     0  <iphone><web-services><html><cordova><html5-vi...
# 18          1     9                                 <android><cordova>
# 19          1    16                <javascript><jquery><jquery-mobile>
#
#                                                 Title  ViewCount  \
# 0   How can I test landscape view using the iPhone...      52618
# 1                            QuickConnect vs Phonegap       4051
# 2   How can I detect a shake gesture in PhoneGap 0.8?       3825
# 3   Why does google.com look different on blackber...       2137
# 4   Mobile Development for iPhone, Android, and Bl...       1452
# 5            jQuery and mobile browser compatibility?      27984
# 6                      Drupal JSON POST from PhoneGap       4431
# 7    Getting Search Keyboard on iPhone using PhoneGap       9717
# 8   iPhone UIWebview: How to force a numeric keybo...      62411
# 9         How to add home button using jquery-mobile?      39408
# 10  Writing a javascript conditional - active/inac...        647
# 11                     HTML5 & XML in PhoneGap Iphone        817
# 12                     Native UIControls with jqTouch       1875
# 13                     Sencha Touch or jQuery Mobile?      41905
# 14                          Sencha Touch Tab Handlers      12549
# 15  how to update my sencha app from Extjs2 to Ext...       1406
# 16                            sencha touch and charts      10261
# 17                            HTML5 with Web Services        939
# 18                     android / phonegap performance       4992
# 19  jQuery Mobile - Dynamically creating form elem...      25220
#
#                                                Answer  \
# 0   <p><img src="https://i.imgur.com/zKnTZ9Y.png?1...
# 1   <p>I found Phonegap to be the easiest to use. ...
# 2   <p>Your first link is using <code>PhoneGap.Ges...
# 3   <p>Disclaimer: I don't know anything about pho...
# 4   <p>There are about 3 different frameworks, Pho...
# 5   <p>jQuery should work fine on at least the And...
# 6   <p>So i figured it out, It had to do with conf...
# 7   <p>Use</p>\n\n<pre><code>&lt;form&gt; ...\n&lt...
# 8   <p>It looks like Mobile Safari supports the ne...
# 9   <p>Without modifying the jquery-mobile.js sour...
# 10  <p>My javascript is rusty, so forgive the synt...
# 11  <p>Your going to have to use Javascript, wheth...
# 12  <p>I've worked out the best method to get this...
# 13  <p>I've been using jQuery mobile for a while n...
# 14  <p>Add after items:</p>\n\n<pre><code>listener...
# 15  <p>You should look at the <a href="http://www....
# 16  <p>I was under the impression that Raphael (<a...
# 17                        <p>Yes on all counts.</p>\n
# 18  <p>The performance of PhoneGap apps is good, b...
# 19  <p>This is messing around in undocumented inte...
#
#                  AnswerDate  AnswerDiff  \
# 0   2009-01-24 05:37:23.413      1229.0
# 1   2009-06-05 18:09:59.420      2955.0
# 2   2010-01-07 12:58:00.680    116951.0
# 3   2009-05-11 14:11:01.043    298882.0
# 4   2009-06-03 20:34:54.970    150359.0
# 5   2010-02-09 23:28:09.117       203.0
# 6   2009-11-24 23:10:18.710     23315.0
# 7   2010-02-11 08:57:49.847   1949981.0
# 8   2009-10-01 18:57:12.590  14086255.0
# 9   2010-11-16 15:27:45.693    510099.0
# 10  2010-10-15 03:46:48.900       413.0
# 11  2010-10-20 15:28:31.630     50121.0
# 12  2010-10-20 22:47:07.143    581367.0
# 13  2010-11-03 17:35:34.937    229794.0
# 14  2010-10-15 11:45:37.683    491078.0
# 15  2010-11-16 21:59:04.517     24766.0
# 16  2010-11-22 14:39:17.303   3035680.0
# 17  2010-10-21 03:59:02.170      4878.0
# 18  2010-06-19 19:32:42.657     25483.0
# 19  2010-10-29 05:32:34.143     95490.0
#
#                                              Combined  AcceptedAnswerCount
# 0   How can I test landscape view using the iPhone...                    1
# 1   QuickConnect vs Phonegap <p>What JavaScript Mo...                    1
# 2   How can I detect a shake gesture in PhoneGap 0...                    1
# 3   Why does google.com look different on blackber...                    1
# 4   Mobile Development for iPhone, Android, and Bl...                    1
# 5   jQuery and mobile browser compatibility? <p>I ...                    1
# 6   Drupal JSON POST from PhoneGap <p>I am trying ...                    1
# 7   Getting Search Keyboard on iPhone using PhoneG...                    1
# 8   iPhone UIWebview: How to force a numeric keybo...                    1
# 9   How to add home button using jquery-mobile? <p...                    1
# 10  Writing a javascript conditional - active/inac...                    1
# 11  HTML5 & XML in PhoneGap Iphone <p>Let said cur...                    1
# 12  Native UIControls with jqTouch <p>After experi...                    1
# 13  Sencha Touch or jQuery Mobile? <p>I wonder if ...                    1
# 14  Sencha Touch Tab Handlers <p>I'm trying to do ...                    1
# 15  how to update my sencha app from Extjs2 to Ext...                    1
# 16  sencha touch and charts <p>Has anyone been abl...                    1
# 17  HTML5 with Web Services <p>Now the case, I wan...                    1
# 18  android / phonegap performance <p>I've read ab...                    1
# 19  jQuery Mobile - Dynamically creating form elem...                    1
#
# [20 rows x 25 columns]
# C:\tools\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
reviews_datasets.dropna()


# obody = reviews_datasets['Body']

# changed to append both title and body
reviews_datasets['CombinedTitleBody'] = reviews_datasets['Title']+' '+reviews_datasets['Body']
#reviews_datasets['CombinedTitleBody'] = reviews_datasets['Combined']
obody = reviews_datasets['CombinedTitleBody']
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
reviews_datasets.head()
#print(obody)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         Id  AcceptedAnswerId  AnswerCount  \
# 0   475553            475576            3
# 1   957076            957273            4
# 2  2010956           2020385            1
# 3   838069            848302            5
# 4   937724            947072            2
#
#                                                 Body               ClosedDate  \
# 0  <p>I wonder if I can test landscape view using...                      NaN
# 1  <p>What JavaScript Mobile development tool wou...  2015-04-20 17:02:40.937
# 2  <p>I'm using PhoneGap 0.8 and I'd like to dete...                      NaN
# 3  <p>I'm tyring to get phonegap up and running o...                      NaN
# 4  <p>I recently stumbled into PhoneGap and I lov...                      NaN
#
#    CommentCount CommunityOwnedDate             CreationDate  FavoriteCount  \
# 0             0                NaN  2009-01-24 05:16:54.267              5
# 1             0                NaN  2009-06-05 17:20:44.613              1
# 2             0                NaN  2010-01-06 04:28:49.527              3
# 3             3                NaN  2009-05-08 03:09:39.223              1
# 4             3                NaN  2009-06-02 02:48:55.373              5
#
#           LastActivityDate  ... Score  \
# 0  2016-11-16 12:31:53.453  ...    42
# 1  2010-02-16 17:38:44.317  ...     3
# 2  2010-03-02 07:48:13.103  ...     2
# 3  2019-03-15 23:01:25.430  ...     3
# 4  2010-03-05 15:51:13.780  ...     4
#
#                                                 Tags  \
# 0              <cocoa-touch><cordova><ios-simulator>
# 1        <javascript><iphone><android><cordova><xui>
# 2  <iphone><accelerometer><cordova><gesture-recog...
# 3  <browser><blackberry><touchscreen><cordova><ri...
# 4             <iphone><android><blackberry><cordova>
#
#                                                Title  ViewCount  \
# 0  How can I test landscape view using the iPhone...      52618
# 1                           QuickConnect vs Phonegap       4051
# 2  How can I detect a shake gesture in PhoneGap 0.8?       3825
# 3  Why does google.com look different on blackber...       2137
# 4  Mobile Development for iPhone, Android, and Bl...       1452
#
#                                               Answer               AnswerDate  \
# 0  <p><img src="https://i.imgur.com/zKnTZ9Y.png?1...  2009-01-24 05:37:23.413
# 1  <p>I found Phonegap to be the easiest to use. ...  2009-06-05 18:09:59.420
# 2  <p>Your first link is using <code>PhoneGap.Ges...  2010-01-07 12:58:00.680
# 3  <p>Disclaimer: I don't know anything about pho...  2009-05-11 14:11:01.043
# 4  <p>There are about 3 different frameworks, Pho...  2009-06-03 20:34:54.970
#
#    AnswerDiff                                           Combined  \
# 0      1229.0  How can I test landscape view using the iPhone...
# 1      2955.0  QuickConnect vs Phonegap <p>What JavaScript Mo...
# 2    116951.0  How can I detect a shake gesture in PhoneGap 0...
# 3    298882.0  Why does google.com look different on blackber...
# 4    150359.0  Mobile Development for iPhone, Android, and Bl...
#
#   AcceptedAnswerCount                                  CombinedTitleBody
# 0                   1  How can I test landscape view using the iPhone...
# 1                   1  QuickConnect vs Phonegap <p>What JavaScript Mo...
# 2                   1  How can I detect a shake gesture in PhoneGap 0...
# 3                   1  Why does google.com look different on blackber...
# 4                   1  Mobile Development for iPhone, Android, and Bl...
#
# [5 rows x 26 columns]

# %%
from nltk import ngrams
from nltk.tokenize import sent_tokenize
import nltk

import re
from nltk.corpus import stopwords
from nltk.tokenize import ToktokTokenizer
from nltk.stem.snowball import SnowballStemmer
from bs4 import BeautifulSoup

tokenizer = ToktokTokenizer()
stemmer = SnowballStemmer('english')
stop_words = set(stopwords.words('english'))
stop_words.update(['.',',','"',"'",'?','!',':', ";",', ',',  ',',   ', '(',')','[',']','{','}','#','...','--',"'s",'also',
                      '&','-','--','=','known','mi','km','$',"'",'`'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def transform_text(text): 

    soup = BeautifulSoup(text)
    for elm in soup.find_all():
        if '<code>'== str(elm)[0:6]:
            elm.decompose()
    textStr = str(soup.get_text())
    textStr = textStr.replace('<html>','')
    textStr = textStr.replace('</html>','')
    textStr = textStr.replace('<body>','')
    textStr = textStr.replace('</body>','')
    textStr = textStr.replace('<p>','')
    textStr = textStr.replace('</p>','')
    textStr = textStr.replace('<pre>','')
    textStr = textStr.replace('</pre>','')
    
    #     remove lines
    textStr = textStr.strip()
    # remove numbers
    textStr = re.sub(r"\d","", textStr)
    
    return textStr
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(transform_text('<p>hello there I will kill you. Then I will be playing cricket <code>I am inside code</code> </p>134'))
# Out:
# hello there I will kill you. Then I will be playing cricket
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import re

# Convert to list
data = reviews_datasets.CombinedTitleBody.values.tolist()

# Remove new line characters
data = [re.sub(r'\s+', ' ', sent) for sent in data]
data = [transform_text(sent) for sent in data]

# Remove distracting single and double quotes
data = [re.sub("\'", "", sent) for sent in data]
data = [re.sub('\", "', '', sent) for sent in data]
data = [re.sub('\\"', '', sent) for sent in data]
data = [re.sub('\"', '', sent) for sent in data]
data = [re.sub('[\\:"]', '', sent) for sent in data]

# Remove web links
data = [re.sub(r'^https?:\/\/.*[\r\n]*', '', sent) for sent in data]

print(data[:3])
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['How can I test landscape view using the iPhone Simulator? I wonder if I can test landscape view using simulator?', 'QuickConnect vs Phonegap What JavaScript Mobile development tool would you use based on momentum, existing documentation and functionality, and ability to get passed the App Stores strict policies?', 'How can I detect a shake gesture in PhoneGap .? Im using PhoneGap . and Id like to detect a basic shake gesture. Ive found two relevant snippets http//groups.google.com/group/phonegap/browse_thread/thread/bebef http//phonegap.pbworks.com/Handling-Shake-Events Neither of them are working for me. Unfortunately the documentation seems a little outdated and the API reference for PhoneGap is just a bunch of tests. I know it can be done I just dont have a known good starting point. If anyone can provide a short snippet of shake detection code for PhoneGap that they know works for them I would be much obliged. Thanks for your time!']

# %%
# Tokenize words and text clean up
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:3])
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['how', 'can', 'test', 'landscape', 'view', 'using', 'the', 'iphone', 'simulator', 'wonder', 'if', 'can', 'test', 'landscape', 'view', 'using', 'simulator'], ['quickconnect', 'vs', 'phonegap', 'what', 'javascript', 'mobile', 'development', 'tool', 'would', 'you', 'use', 'based', 'on', 'momentum', 'existing', 'documentation', 'and', 'functionality', 'and', 'ability', 'to', 'get', 'passed', 'the', 'app', 'stores', 'strict', 'policies'], ['how', 'can', 'detect', 'shake', 'gesture', 'in', 'phonegap', 'im', 'using', 'phonegap', 'and', 'id', 'like', 'to', 'detect', 'basic', 'shake', 'gesture', 'ive', 'found', 'two', 'relevant', 'snippets', 'http', 'groups', 'google', 'com', 'group', 'phonegap', 'browse_thread', 'thread', 'bebef', 'http', 'phonegap', 'pbworks', 'com', 'handling', 'shake', 'events', 'neither', 'of', 'them', 'are', 'working', 'for', 'me', 'unfortunately', 'the', 'documentation', 'seems', 'little', 'outdated', 'and', 'the', 'api', 'reference', 'for', 'phonegap', 'is', 'just', 'bunch', 'of', 'tests', 'know', 'it', 'can', 'be', 'done', 'just', 'dont', 'have', 'known', 'good', 'starting', 'point', 'if', 'anyone', 'can', 'provide', 'short', 'snippet', 'of', 'shake', 'detection', 'code', 'for', 'phonegap', 'that', 'they', 'know', 'works', 'for', 'them', 'would', 'be', 'much', 'obliged', 'thanks', 'for', 'your', 'time']]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=75) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=75)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# See trigram example
print(trigram_mod[bigram_mod[data_words[3]]])
# Out:
# ['why', 'does', 'google', 'com', 'look', 'different', 'on', 'blackberry', 'phonegap', 'vs', 'blackberry', 'browser', 'im', 'tyring', 'to', 'get', 'phonegap', 'up', 'and', 'running', 'on', 'blackberry', 'storm', 'simulator', 'had', 'been', 'testing', 'my', 'webapp', 'from', 'withing', 'bbs', 'built', 'in', 'browser', 'and', 'it', 'was', 'looking', 'ok', 'but', 'then', 'it', 'totally', 'bit', 'once', 'tried', 'to', 'look', 'at', 'the', 'some', 'code', 'from', 'within', 'phonegap', 'even', 'though', 'was', 'pointing', 'phonegap', 'to', 'the', 'same', 'url', 'hadnt', 'yet', 'gotten', 'to', 'the', 'point', 'of', 'running', 'code', 'locally', 'on', 'the', 'device', 'tried', 'test', 'case', 'on', 'google', 'and', 'got', 'similiar', 'results', 'see', 'below', 'suspect', 'that', 'im', 'missing', 'something', 'basic', 'here', 'would', 'have', 'expect', 'both', 'images', 'to', 'be', 'nearly_identical', 'browser', 'http', 'www', 'com', 'outside', 'jpg', 'phonegap', 'http', 'www', 'com', 'outside', 'jpg', 'update', 'to', 'shed', 'some', 'light', 'on', 'what', 'is', 'happening', 'ran', 'the', 'browser', 'and', 'the', 'embedded', 'browser', 'phonegap', 'against', 'the', 'mobile', 'web', 'acid', 'test', 'http', 'www', 'org', 'mobile', 'test', 'definitely', 'notice', 'differences_between', 'the', 'two', 'but', 'dont', 'yet', 'know', 'the', 'why', 'and', 'the', 'how', 'to', 'address', 'acid', 'via', 'built', 'in', 'browser', 'source', 'com', 'btw', 'ran', 'this', 'earlier', 'today', 'and', 'got', 'couple', 'more', 'green', 'square', 'than', 'just', 'now', 'acid', 'via', 'browser', 'embedded', 'into', 'phonegap', 'http', 'www', 'com', 'outside', 'jpg']
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
spacy.load('en_core_web_sm')
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
#spacy.load('en_core_web_sm')

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
reviews_datasets.head(20)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          Id  AcceptedAnswerId  AnswerCount  \
# 0    475553            475576            3
# 1    957076            957273            4
# 2   2010956           2020385            1
# 3    838069            848302            5
# 4    937724            947072            2
# 5   2233292           2233312            7
# 6   1791298           1793588            1
# 7   2096328           2243265            3
# 8    773843           1505805           10
# 9   4147376           4195753            4
# 10  3939333           3939364            1
# 11  3974122           3979543            1
# 12  3930277           3982919            2
# 13  4066167           4089874           20
# 14  3897530           3941900            2
# 15  4195534           4199452            2
# 16  3958612           4246540            7
# 17  3983893           3984181            1
# 18  3075468           3076946            4
# 19  4039428           4049250            8
#
#                                                  Body  \
# 0   <p>I wonder if I can test landscape view using...
# 1   <p>What JavaScript Mobile development tool wou...
# 2   <p>I'm using PhoneGap 0.8 and I'd like to dete...
# 3   <p>I'm tyring to get phonegap up and running o...
# 4   <p>I recently stumbled into PhoneGap and I lov...
# 5   <p>I want to build a relatively simple version...
# 6   <p>I am trying to send a POST request to Drupa...
# 7   <p>I have created a search field on a mobile a...
# 8   <p>I'm experimenting with PhoneGap to develop ...
# 9   <p>By default jquery-mobile adds a back button...
# 10  <p>I have this script, which works great at th...
# 11  <p>Let said currently I want to pull a XML fil...
# 12  <p>After experimenting with a bunch of javascr...
# 13  <p>I wonder if I were to develop a mobile Web ...
# 14  <p>I'm trying to do a Tabpanel in Sencha Touch...
# 15  <p>i'm trying to update my sencha app from Ext...
# 16  <p>Has anyone been able to incorporate Charts ...
# 17  <p>Now the case, I want to develop a iPhone ap...
# 18  <p>I've read about phonegap which enables user...
# 19  <p>I'm creating a web-database driven offline ...
#
#                  ClosedDate  CommentCount CommunityOwnedDate  \
# 0                       NaN             0                NaN
# 1   2015-04-20 17:02:40.937             0                NaN
# 2                       NaN             0                NaN
# 3                       NaN             3                NaN
# 4                       NaN             3                NaN
# 5                       NaN             2                NaN
# 6                       NaN             1                NaN
# 7                       NaN             0                NaN
# 8                       NaN             3                NaN
# 9                       NaN             1                NaN
# 10                      NaN             0                NaN
# 11                      NaN             0                NaN
# 12                      NaN             0                NaN
# 13  2014-09-03 05:32:05.810             2                NaN
# 14                      NaN             0                NaN
# 15                      NaN             0                NaN
# 16                      NaN             0                NaN
# 17                      NaN             0                NaN
# 18  2012-08-21 03:57:45.833             0                NaN
# 19                      NaN             0                NaN
#
#                CreationDate  FavoriteCount         LastActivityDate  ...  \
# 0   2009-01-24 05:16:54.267              5  2016-11-16 12:31:53.453  ...
# 1   2009-06-05 17:20:44.613              1  2010-02-16 17:38:44.317  ...
# 2   2010-01-06 04:28:49.527              3  2010-03-02 07:48:13.103  ...
# 3   2009-05-08 03:09:39.223              1  2019-03-15 23:01:25.430  ...
# 4   2009-06-02 02:48:55.373              5  2010-03-05 15:51:13.780  ...
# 5   2010-02-09 23:24:46.513              5  2014-03-19 12:31:42.353  ...
# 6   2009-11-24 16:41:43.087              1  2010-06-09 21:00:08.937  ...
# 7   2010-01-19 19:18:08.563              3  2018-05-07 15:46:24.907  ...
# 8   2009-04-21 18:06:17.257             19  2017-12-10 15:59:36.850  ...
# 9   2010-11-10 17:46:06.757              6  2011-09-14 17:01:29.040  ...
# 10  2010-10-15 03:39:55.360              0  2010-10-15 18:58:23.973  ...
# 11  2010-10-20 01:33:10.283              0  2010-10-20 15:28:31.630  ...
# 12  2010-10-14 05:17:40.483              1  2010-10-20 22:47:07.143  ...
# 13  2010-11-01 01:45:40.650             30  2014-07-01 12:31:53.317  ...
# 14  2010-10-09 19:20:59.220              2  2011-03-14 14:37:33.940  ...
# 15  2010-11-16 15:06:18.277              0  2013-04-22 20:29:11.283  ...
# 16  2010-10-18 11:24:37.663              2  2013-03-17 08:56:42.577  ...
# 17  2010-10-21 02:37:44.493              1  2010-10-21 03:59:02.170  ...
# 18  2010-06-19 12:27:59.117              2  2012-04-17 22:44:48.960  ...
# 19  2010-10-28 03:01:04.310              4  2012-01-05 09:05:20.293  ...
#
#    Score                                               Tags  \
# 0     42              <cocoa-touch><cordova><ios-simulator>
# 1      3        <javascript><iphone><android><cordova><xui>
# 2      2  <iphone><accelerometer><cordova><gesture-recog...
# 3      3  <browser><blackberry><touchscreen><cordova><ri...
# 4      4             <iphone><android><blackberry><cordova>
# 5     20   <jquery><iphone><android><mobile><jquery-mobile>
# 6      0             <iphone><json><drupal><jsonp><cordova>
# 7      7                      <javascript><iphone><cordova>
# 8     61             <iphone><keyboard><uiwebview><cordova>
# 9     18                <javascript><jquery><jquery-mobile>
# 10     0          <javascript><xcode><conditional><cordova>
# 11     0         <iphone><xml><web-services><html><cordova>
# 12     0  <uitabbarcontroller><uitabbar><jqtouch><cordov...
# 13    69  <jquery-mobile><web-applications><sencha-touch...
# 14     3                  <javascript><extjs><sencha-touch>
# 15     3                              <extjs><sencha-touch>
# 16     9               <graph><charts><sencha-touch><extjs>
# 17     0  <iphone><web-services><html><cordova><html5-vi...
# 18     9                                 <android><cordova>
# 19    16                <javascript><jquery><jquery-mobile>
#
#                                                 Title  ViewCount  \
# 0   How can I test landscape view using the iPhone...      52618
# 1                            QuickConnect vs Phonegap       4051
# 2   How can I detect a shake gesture in PhoneGap 0.8?       3825
# 3   Why does google.com look different on blackber...       2137
# 4   Mobile Development for iPhone, Android, and Bl...       1452
# 5            jQuery and mobile browser compatibility?      27984
# 6                      Drupal JSON POST from PhoneGap       4431
# 7    Getting Search Keyboard on iPhone using PhoneGap       9717
# 8   iPhone UIWebview: How to force a numeric keybo...      62411
# 9         How to add home button using jquery-mobile?      39408
# 10  Writing a javascript conditional - active/inac...        647
# 11                     HTML5 & XML in PhoneGap Iphone        817
# 12                     Native UIControls with jqTouch       1875
# 13                     Sencha Touch or jQuery Mobile?      41905
# 14                          Sencha Touch Tab Handlers      12549
# 15  how to update my sencha app from Extjs2 to Ext...       1406
# 16                            sencha touch and charts      10261
# 17                            HTML5 with Web Services        939
# 18                     android / phonegap performance       4992
# 19  jQuery Mobile - Dynamically creating form elem...      25220
#
#                                                Answer  \
# 0   <p><img src="https://i.imgur.com/zKnTZ9Y.png?1...
# 1   <p>I found Phonegap to be the easiest to use. ...
# 2   <p>Your first link is using <code>PhoneGap.Ges...
# 3   <p>Disclaimer: I don't know anything about pho...
# 4   <p>There are about 3 different frameworks, Pho...
# 5   <p>jQuery should work fine on at least the And...
# 6   <p>So i figured it out, It had to do with conf...
# 7   <p>Use</p>\n\n<pre><code>&lt;form&gt; ...\n&lt...
# 8   <p>It looks like Mobile Safari supports the ne...
# 9   <p>Without modifying the jquery-mobile.js sour...
# 10  <p>My javascript is rusty, so forgive the synt...
# 11  <p>Your going to have to use Javascript, wheth...
# 12  <p>I've worked out the best method to get this...
# 13  <p>I've been using jQuery mobile for a while n...
# 14  <p>Add after items:</p>\n\n<pre><code>listener...
# 15  <p>You should look at the <a href="http://www....
# 16  <p>I was under the impression that Raphael (<a...
# 17                        <p>Yes on all counts.</p>\n
# 18  <p>The performance of PhoneGap apps is good, b...
# 19  <p>This is messing around in undocumented inte...
#
#                  AnswerDate  AnswerDiff  \
# 0   2009-01-24 05:37:23.413      1229.0
# 1   2009-06-05 18:09:59.420      2955.0
# 2   2010-01-07 12:58:00.680    116951.0
# 3   2009-05-11 14:11:01.043    298882.0
# 4   2009-06-03 20:34:54.970    150359.0
# 5   2010-02-09 23:28:09.117       203.0
# 6   2009-11-24 23:10:18.710     23315.0
# 7   2010-02-11 08:57:49.847   1949981.0
# 8   2009-10-01 18:57:12.590  14086255.0
# 9   2010-11-16 15:27:45.693    510099.0
# 10  2010-10-15 03:46:48.900       413.0
# 11  2010-10-20 15:28:31.630     50121.0
# 12  2010-10-20 22:47:07.143    581367.0
# 13  2010-11-03 17:35:34.937    229794.0
# 14  2010-10-15 11:45:37.683    491078.0
# 15  2010-11-16 21:59:04.517     24766.0
# 16  2010-11-22 14:39:17.303   3035680.0
# 17  2010-10-21 03:59:02.170      4878.0
# 18  2010-06-19 19:32:42.657     25483.0
# 19  2010-10-29 05:32:34.143     95490.0
#
#                                              Combined AcceptedAnswerCount  \
# 0   How can I test landscape view using the iPhone...                   1
# 1   QuickConnect vs Phonegap <p>What JavaScript Mo...                   1
# 2   How can I detect a shake gesture in PhoneGap 0...                   1
# 3   Why does google.com look different on blackber...                   1
# 4   Mobile Development for iPhone, Android, and Bl...                   1
# 5   jQuery and mobile browser compatibility? <p>I ...                   1
# 6   Drupal JSON POST from PhoneGap <p>I am trying ...                   1
# 7   Getting Search Keyboard on iPhone using PhoneG...                   1
# 8   iPhone UIWebview: How to force a numeric keybo...                   1
# 9   How to add home button using jquery-mobile? <p...                   1
# 10  Writing a javascript conditional - active/inac...                   1
# 11  HTML5 & XML in PhoneGap Iphone <p>Let said cur...                   1
# 12  Native UIControls with jqTouch <p>After experi...                   1
# 13  Sencha Touch or jQuery Mobile? <p>I wonder if ...                   1
# 14  Sencha Touch Tab Handlers <p>I'm trying to do ...                   1
# 15  how to update my sencha app from Extjs2 to Ext...                   1
# 16  sencha touch and charts <p>Has anyone been abl...                   1
# 17  HTML5 with Web Services <p>Now the case, I wan...                   1
# 18  android / phonegap performance <p>I've read ab...                   1
# 19  jQuery Mobile - Dynamically creating form elem...                   1
#
#                                     CombinedTitleBody
# 0   How can I test landscape view using the iPhone...
# 1   QuickConnect vs Phonegap <p>What JavaScript Mo...
# 2   How can I detect a shake gesture in PhoneGap 0...
# 3   Why does google.com look different on blackber...
# 4   Mobile Development for iPhone, Android, and Bl...
# 5   jQuery and mobile browser compatibility? <p>I ...
# 6   Drupal JSON POST from PhoneGap <p>I am trying ...
# 7   Getting Search Keyboard on iPhone using PhoneG...
# 8   iPhone UIWebview: How to force a numeric keybo...
# 9   How to add home button using jquery-mobile? <p...
# 10  Writing a javascript conditional - active/inac...
# 11  HTML5 & XML in PhoneGap Iphone <p>Let said cur...
# 12  Native UIControls with jqTouch <p>After experi...
# 13  Sencha Touch or jQuery Mobile? <p>I wonder if ...
# 14  Sencha Touch Tab Handlers <p>I'm trying to do ...
# 15  how to update my sencha app from Extjs2 to Ext...
# 16  sencha touch and charts <p>Has anyone been abl...
# 17  HTML5 with Web Services <p>Now the case, I wan...
# 18  android / phonegap performance <p>I've read ab...
# 19  jQuery Mobile - Dynamically creating form elem...
#
# [20 rows x 26 columns]

# %%
print(data_lemmatized[:2])

reviews_datasets['topics']=data_lemmatized
reviews_datasets['obody']=obody
cview = reviews_datasets['ViewCount'].astype(int)
avgfav = reviews_datasets['FavoriteCount'].astype(int)
avgscore = reviews_datasets['Score'].astype(int)
body = reviews_datasets['Body']
titles = reviews_datasets['Title']
caccepans = reviews_datasets['AcceptedAnswerCount']
ansdelay = reviews_datasets['AnswerDiff']
avgdelay = ansdelay.fillna(0)
reviews_datasets.head(20)
#reset option to default value
# Out:
# [['test', 'landscape', 'view', 'use', 'iphone', 'simulator', 'wonder', 'test', 'landscape', 'view', 'use', 'simulator'], ['quickconnect', 'phonegap', 'javascript', 'mobile', 'development', 'tool', 'use', 'base', 'momentum', 'exist', 'documentation', 'functionality', 'ability', 'get', 'pass', 'app', 'store', 'strict', 'policy']]
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          Id  AcceptedAnswerId  AnswerCount  \
# 0    475553            475576            3
# 1    957076            957273            4
# 2   2010956           2020385            1
# 3    838069            848302            5
# 4    937724            947072            2
# 5   2233292           2233312            7
# 6   1791298           1793588            1
# 7   2096328           2243265            3
# 8    773843           1505805           10
# 9   4147376           4195753            4
# 10  3939333           3939364            1
# 11  3974122           3979543            1
# 12  3930277           3982919            2
# 13  4066167           4089874           20
# 14  3897530           3941900            2
# 15  4195534           4199452            2
# 16  3958612           4246540            7
# 17  3983893           3984181            1
# 18  3075468           3076946            4
# 19  4039428           4049250            8
#
#                                                  Body  \
# 0   <p>I wonder if I can test landscape view using...
# 1   <p>What JavaScript Mobile development tool wou...
# 2   <p>I'm using PhoneGap 0.8 and I'd like to dete...
# 3   <p>I'm tyring to get phonegap up and running o...
# 4   <p>I recently stumbled into PhoneGap and I lov...
# 5   <p>I want to build a relatively simple version...
# 6   <p>I am trying to send a POST request to Drupa...
# 7   <p>I have created a search field on a mobile a...
# 8   <p>I'm experimenting with PhoneGap to develop ...
# 9   <p>By default jquery-mobile adds a back button...
# 10  <p>I have this script, which works great at th...
# 11  <p>Let said currently I want to pull a XML fil...
# 12  <p>After experimenting with a bunch of javascr...
# 13  <p>I wonder if I were to develop a mobile Web ...
# 14  <p>I'm trying to do a Tabpanel in Sencha Touch...
# 15  <p>i'm trying to update my sencha app from Ext...
# 16  <p>Has anyone been able to incorporate Charts ...
# 17  <p>Now the case, I want to develop a iPhone ap...
# 18  <p>I've read about phonegap which enables user...
# 19  <p>I'm creating a web-database driven offline ...
#
#                  ClosedDate  CommentCount CommunityOwnedDate  \
# 0                       NaN             0                NaN
# 1   2015-04-20 17:02:40.937             0                NaN
# 2                       NaN             0                NaN
# 3                       NaN             3                NaN
# 4                       NaN             3                NaN
# 5                       NaN             2                NaN
# 6                       NaN             1                NaN
# 7                       NaN             0                NaN
# 8                       NaN             3                NaN
# 9                       NaN             1                NaN
# 10                      NaN             0                NaN
# 11                      NaN             0                NaN
# 12                      NaN             0                NaN
# 13  2014-09-03 05:32:05.810             2                NaN
# 14                      NaN             0                NaN
# 15                      NaN             0                NaN
# 16                      NaN             0                NaN
# 17                      NaN             0                NaN
# 18  2012-08-21 03:57:45.833             0                NaN
# 19                      NaN             0                NaN
#
#                CreationDate  FavoriteCount         LastActivityDate  ...  \
# 0   2009-01-24 05:16:54.267              5  2016-11-16 12:31:53.453  ...
# 1   2009-06-05 17:20:44.613              1  2010-02-16 17:38:44.317  ...
# 2   2010-01-06 04:28:49.527              3  2010-03-02 07:48:13.103  ...
# 3   2009-05-08 03:09:39.223              1  2019-03-15 23:01:25.430  ...
# 4   2009-06-02 02:48:55.373              5  2010-03-05 15:51:13.780  ...
# 5   2010-02-09 23:24:46.513              5  2014-03-19 12:31:42.353  ...
# 6   2009-11-24 16:41:43.087              1  2010-06-09 21:00:08.937  ...
# 7   2010-01-19 19:18:08.563              3  2018-05-07 15:46:24.907  ...
# 8   2009-04-21 18:06:17.257             19  2017-12-10 15:59:36.850  ...
# 9   2010-11-10 17:46:06.757              6  2011-09-14 17:01:29.040  ...
# 10  2010-10-15 03:39:55.360              0  2010-10-15 18:58:23.973  ...
# 11  2010-10-20 01:33:10.283              0  2010-10-20 15:28:31.630  ...
# 12  2010-10-14 05:17:40.483              1  2010-10-20 22:47:07.143  ...
# 13  2010-11-01 01:45:40.650             30  2014-07-01 12:31:53.317  ...
# 14  2010-10-09 19:20:59.220              2  2011-03-14 14:37:33.940  ...
# 15  2010-11-16 15:06:18.277              0  2013-04-22 20:29:11.283  ...
# 16  2010-10-18 11:24:37.663              2  2013-03-17 08:56:42.577  ...
# 17  2010-10-21 02:37:44.493              1  2010-10-21 03:59:02.170  ...
# 18  2010-06-19 12:27:59.117              2  2012-04-17 22:44:48.960  ...
# 19  2010-10-28 03:01:04.310              4  2012-01-05 09:05:20.293  ...
#
#                                                 Title ViewCount  \
# 0   How can I test landscape view using the iPhone...     52618
# 1                            QuickConnect vs Phonegap      4051
# 2   How can I detect a shake gesture in PhoneGap 0.8?      3825
# 3   Why does google.com look different on blackber...      2137
# 4   Mobile Development for iPhone, Android, and Bl...      1452
# 5            jQuery and mobile browser compatibility?     27984
# 6                      Drupal JSON POST from PhoneGap      4431
# 7    Getting Search Keyboard on iPhone using PhoneGap      9717
# 8   iPhone UIWebview: How to force a numeric keybo...     62411
# 9         How to add home button using jquery-mobile?     39408
# 10  Writing a javascript conditional - active/inac...       647
# 11                     HTML5 & XML in PhoneGap Iphone       817
# 12                     Native UIControls with jqTouch      1875
# 13                     Sencha Touch or jQuery Mobile?     41905
# 14                          Sencha Touch Tab Handlers     12549
# 15  how to update my sencha app from Extjs2 to Ext...      1406
# 16                            sencha touch and charts     10261
# 17                            HTML5 with Web Services       939
# 18                     android / phonegap performance      4992
# 19  jQuery Mobile - Dynamically creating form elem...     25220
#
#                                                Answer  \
# 0   <p><img src="https://i.imgur.com/zKnTZ9Y.png?1...
# 1   <p>I found Phonegap to be the easiest to use. ...
# 2   <p>Your first link is using <code>PhoneGap.Ges...
# 3   <p>Disclaimer: I don't know anything about pho...
# 4   <p>There are about 3 different frameworks, Pho...
# 5   <p>jQuery should work fine on at least the And...
# 6   <p>So i figured it out, It had to do with conf...
# 7   <p>Use</p>\n\n<pre><code>&lt;form&gt; ...\n&lt...
# 8   <p>It looks like Mobile Safari supports the ne...
# 9   <p>Without modifying the jquery-mobile.js sour...
# 10  <p>My javascript is rusty, so forgive the synt...
# 11  <p>Your going to have to use Javascript, wheth...
# 12  <p>I've worked out the best method to get this...
# 13  <p>I've been using jQuery mobile for a while n...
# 14  <p>Add after items:</p>\n\n<pre><code>listener...
# 15  <p>You should look at the <a href="http://www....
# 16  <p>I was under the impression that Raphael (<a...
# 17                        <p>Yes on all counts.</p>\n
# 18  <p>The performance of PhoneGap apps is good, b...
# 19  <p>This is messing around in undocumented inte...
#
#                  AnswerDate  AnswerDiff  \
# 0   2009-01-24 05:37:23.413      1229.0
# 1   2009-06-05 18:09:59.420      2955.0
# 2   2010-01-07 12:58:00.680    116951.0
# 3   2009-05-11 14:11:01.043    298882.0
# 4   2009-06-03 20:34:54.970    150359.0
# 5   2010-02-09 23:28:09.117       203.0
# 6   2009-11-24 23:10:18.710     23315.0
# 7   2010-02-11 08:57:49.847   1949981.0
# 8   2009-10-01 18:57:12.590  14086255.0
# 9   2010-11-16 15:27:45.693    510099.0
# 10  2010-10-15 03:46:48.900       413.0
# 11  2010-10-20 15:28:31.630     50121.0
# 12  2010-10-20 22:47:07.143    581367.0
# 13  2010-11-03 17:35:34.937    229794.0
# 14  2010-10-15 11:45:37.683    491078.0
# 15  2010-11-16 21:59:04.517     24766.0
# 16  2010-11-22 14:39:17.303   3035680.0
# 17  2010-10-21 03:59:02.170      4878.0
# 18  2010-06-19 19:32:42.657     25483.0
# 19  2010-10-29 05:32:34.143     95490.0
#
#                                              Combined  AcceptedAnswerCount  \
# 0   How can I test landscape view using the iPhone...                    1
# 1   QuickConnect vs Phonegap <p>What JavaScript Mo...                    1
# 2   How can I detect a shake gesture in PhoneGap 0...                    1
# 3   Why does google.com look different on blackber...                    1
# 4   Mobile Development for iPhone, Android, and Bl...                    1
# 5   jQuery and mobile browser compatibility? <p>I ...                    1
# 6   Drupal JSON POST from PhoneGap <p>I am trying ...                    1
# 7   Getting Search Keyboard on iPhone using PhoneG...                    1
# 8   iPhone UIWebview: How to force a numeric keybo...                    1
# 9   How to add home button using jquery-mobile? <p...                    1
# 10  Writing a javascript conditional - active/inac...                    1
# 11  HTML5 & XML in PhoneGap Iphone <p>Let said cur...                    1
# 12  Native UIControls with jqTouch <p>After experi...                    1
# 13  Sencha Touch or jQuery Mobile? <p>I wonder if ...                    1
# 14  Sencha Touch Tab Handlers <p>I'm trying to do ...                    1
# 15  how to update my sencha app from Extjs2 to Ext...                    1
# 16  sencha touch and charts <p>Has anyone been abl...                    1
# 17  HTML5 with Web Services <p>Now the case, I wan...                    1
# 18  android / phonegap performance <p>I've read ab...                    1
# 19  jQuery Mobile - Dynamically creating form elem...                    1
#
#                                     CombinedTitleBody  \
# 0   How can I test landscape view using the iPhone...
# 1   QuickConnect vs Phonegap <p>What JavaScript Mo...
# 2   How can I detect a shake gesture in PhoneGap 0...
# 3   Why does google.com look different on blackber...
# 4   Mobile Development for iPhone, Android, and Bl...
# 5   jQuery and mobile browser compatibility? <p>I ...
# 6   Drupal JSON POST from PhoneGap <p>I am trying ...
# 7   Getting Search Keyboard on iPhone using PhoneG...
# 8   iPhone UIWebview: How to force a numeric keybo...
# 9   How to add home button using jquery-mobile? <p...
# 10  Writing a javascript conditional - active/inac...
# 11  HTML5 & XML in PhoneGap Iphone <p>Let said cur...
# 12  Native UIControls with jqTouch <p>After experi...
# 13  Sencha Touch or jQuery Mobile? <p>I wonder if ...
# 14  Sencha Touch Tab Handlers <p>I'm trying to do ...
# 15  how to update my sencha app from Extjs2 to Ext...
# 16  sencha touch and charts <p>Has anyone been abl...
# 17  HTML5 with Web Services <p>Now the case, I wan...
# 18  android / phonegap performance <p>I've read ab...
# 19  jQuery Mobile - Dynamically creating form elem...
#
#                                                topics  \
# 0   [test, landscape, view, use, iphone, simulator...
# 1   [quickconnect, phonegap, javascript, mobile, d...
# 2   [detect, shake_gesture, phonegap, m, use, phon...
# 3   [google, com, look, different, blackberry, pho...
# 4   [mobile, development, iphone, android, blackbe...
# 5   [jquery, mobile, browser, compatibility, want,...
# 6   [drupal, json, post, phonegap, try, send, post...
# 7   [get, search, keyboard, iphone, use, phonegap,...
# 8   [iphone, uiwebview, force, numeric_keyboard, p...
# 9   [add, home, button, use, jquery, mobile, defau...
# 10  [write, javascript, conditional, active, inact...
# 11  [html, xml, phonegap, iphone, let, say, curren...
# 12  [native, uicontrol, jqtouch, experiment, bunch...
# 13  [sencha_touch, jquery, mobile, wonder, develop...
# 14  [sencha_touch, tab, handler, m, try, tabpanel,...
# 15  [update, sencha, app, extjs, extjs, m, try, up...
# 16  [sencha_touch, chart, able, incorporate, chart...
# 17  [html, web, service, case, want, develop, ipho...
# 18  [android, phonegap, performance, ve, read, pho...
# 19  [jquery, mobile, dynamically, create, form, el...
#
#                                                 obody
# 0   How can I test landscape view using the iPhone...
# 1   QuickConnect vs Phonegap <p>What JavaScript Mo...
# 2   How can I detect a shake gesture in PhoneGap 0...
# 3   Why does google.com look different on blackber...
# 4   Mobile Development for iPhone, Android, and Bl...
# 5   jQuery and mobile browser compatibility? <p>I ...
# 6   Drupal JSON POST from PhoneGap <p>I am trying ...
# 7   Getting Search Keyboard on iPhone using PhoneG...
# 8   iPhone UIWebview: How to force a numeric keybo...
# 9   How to add home button using jquery-mobile? <p...
# 10  Writing a javascript conditional - active/inac...
# 11  HTML5 & XML in PhoneGap Iphone <p>Let said cur...
# 12  Native UIControls with jqTouch <p>After experi...
# 13  Sencha Touch or jQuery Mobile? <p>I wonder if ...
# 14  Sencha Touch Tab Handlers <p>I'm trying to do ...
# 15  how to update my sencha app from Extjs2 to Ext...
# 16  sencha touch and charts <p>Has anyone been abl...
# 17  HTML5 with Web Services <p>Now the case, I wan...
# 18  android / phonegap performance <p>I've read ab...
# 19  jQuery Mobile - Dynamically creating form elem...
#
# [20 rows x 28 columns]

# %%
reviews_datasets.to_csv("D:/so-data/output1.csv")
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import os
from gensim.models.wrappers import LdaMallet

os.environ['MALLET_HOME'] = 'D:\\so-data\\mallet-2.0.8\\mallet-2.0.8'

mallet_path = 'D:\\so-data\\mallet-2.0.8\\mallet-2.0.8\\bin\\mallet'
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# lda_mallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=30, id2word=id2word, optimize_interval=10, iterations=1500)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# gensim.models.LdaModel?
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Compute Coherence Score
# coherence_model_ldamallet = CoherenceModel(model=lda_mallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
# coherence_ldamallet = coherence_model_ldamallet.get_coherence()
# print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=15, step=5):
    """
    Compute c_v coherence for various number of topics
    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics
    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        print(num_topics)
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=5, limit=55, step=5)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
#Show graph
limit=55; start=5; step=5;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# print(coherence_values)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def calculate_best_iterations(number_of_topics, number_of_iterations):
    print(number_of_iterations)
    lda_mallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus = corpus, num_topics= number_of_topics, id2word= id2word, iterations= number_of_iterations)
    coherence_model_ldamallet = CoherenceModel(model=lda_mallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
    iterations.append(number_of_iterations)
    iteration_based_coherence_values.append(coherence_model_ldamallet.get_coherence())
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
iterations = []
iteration_based_coherence_values = []

for i in [500,1000,1500,2000,2500, 3000]:
    calculate_best_iterations(30, i)

#Show graph
limit=3000; start=500; step=500;
x = range(start, limit, step)
plt.plot(x, iteration_based_coherence_values)
plt.xlabel("Num of iterations")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-7e1ecedb98d2> in <module>
#       8 limit=3000; start=500; step=500;
#       9 x = range(start, limit, step)
# ---> 10 plt.plot(x, iteration_based_coherence_values)
#      11 plt.xlabel("Num of iterations")
#      12 plt.ylabel("Coherence score")
#
# C:\tools\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\tools\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# C:\tools\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# C:\tools\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (5,) and (6,)

# %%
for i in iteration_based_coherence_values:
    print(i)
# Out:
# 0.546009138477492
# 0.5462120462095679
# 0.5492103904216186
# 0.5568327765414263
# 0.5600011946910506
# 0.5595257401960215
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Show graph
limit=3000; start=500; step=500;
x = range(start, limit, step)
plt.plot(x, iteration_based_coherence_values)
plt.xlabel("Num of iterations")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
lda_mallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=30, id2word=id2word, iterations=2500, alpha=5)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#print topics

#print(lda_mallet.show_topics(num_topics=-1, num_words=25, formatted=False))
topic_number = []
topics = []

for i in lda_mallet.show_topics(num_topics=50, num_words=10, formatted=False):
    value_map_keyword = {}
    value_list = []
    key_words_list = []
    for j in i[1]:
        value_map_keyword[j[1]] = j[0]
        value_list.append(j[1])
        key_words_list.append(j[0])
   
    topic_number.append(i[0]+1)
    topics.append(',  '.join(map(str, key_words_list)))
    
topic_dataframe = pd.DataFrame({'Topic-Number': topic_number, 'Keywords': topics})
topic_dataframe.to_csv("D:/so-data/final-data/cordova_topic_keywords.csv")
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
###################################
# topic development
###################################

def format_topics_sentences(ldamodel=lda_mallet, corpus=corpus, texts=data_lemmatized, title=data_lemmatized):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    contents2 = pd.Series(title)
    sent_topics_df = pd.concat([sent_topics_df, contents2, contents], axis=1)
    return(sent_topics_df)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_mallet, corpus=corpus, texts=body, title=titles)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'title', 'texts']
df_dominant_topic.to_csv("D:/so-data/final-data/final_topics_cordova.csv")
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
